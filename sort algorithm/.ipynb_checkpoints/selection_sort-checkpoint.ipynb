# %% [markdown]
# * Author: Ethan
# ![截圖 2022-09-30 上午10.32.13.png](attachment:82f7a6e2-6a32-41c6-bb59-4417c1f61d11.png)

# %%
nums = [4,1,2,3,7]

# %%
def selection_sort(nums):
    start_idx = 0

    while start_idx < len(nums):
        tmp_min = float('inf')
        # search
        for i, n in enumerate(nums[start_idx:]):
            if n < tmp_min:
                tmp_min = n
                tmp_min_idx = i   
        # switch
        nums[start_idx], nums[start_idx+tmp_min_idx] = nums[start_idx+tmp_min_idx], nums[start_idx]
        start_idx += 1

    return nums

# %%
selection_sort(nums)
# Out:
# [1, 2, 3, 4, 7]
