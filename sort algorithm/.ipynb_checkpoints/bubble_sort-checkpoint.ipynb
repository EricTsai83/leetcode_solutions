# %% [markdown]
# * Author: Ethan
# ![截圖 2022-09-30 上午10.36.55.png](attachment:690abb16-a779-4b6f-b933-91135fc31757.png)
# ![截圖 2022-09-30 上午10.37.00.png](attachment:83d4f46a-b915-4f97-afa1-974f42ef0a5f.png)
# ![截圖 2022-09-30 上午10.37.09.png](attachment:0d91dc7a-20a0-440e-91e8-7f7a255af972.png)

# %%
nums = [4, 2, 7, 1, 3]

# %%
def bubble_sort(nums):
    '''
    init: 
    unsorted_last_idx: 最後一個遍歷的元素idx
    sorted: 這個數列有沒有被排序過
    -------------------------------------
    time complexity: (N+1)*N/2
    hint: 如果要做two-pointer & shift的元素間距為1, 有個小技巧idx的init先-1, 遍歷的時候用+1才不會溢位
    '''
    unsorted_last_idx = len(nums) - 1
    sorted = False

    while not sorted:
        sorted = True # break condition
        for i in range(unsorted_last_idx):
            if nums[i] > nums[i+1]:
                sorted = False
                nums[i], nums[i+1] = nums[i+1], nums[i]
        unsorted_last_idx -= 1
        print(f'unsorted_last_idx: {unsorted_last_idx}','\n',
              f'nums: {nums}','\n','-'*70)

    return nums

bubble_sort(nums = [4, 2, 7, 1, 3])
# Out:
# unsorted_last_idx: 3
#  nums: [2, 4, 1, 3, 7]
#  ----------------------------------------------------------------------
# unsorted_last_idx: 2
#  nums: [2, 1, 3, 4, 7]
#  ----------------------------------------------------------------------
# unsorted_last_idx: 1
#  nums: [1, 2, 3, 4, 7]
#  ----------------------------------------------------------------------
# unsorted_last_idx: 0
#  nums: [1, 2, 3, 4, 7]
#  ----------------------------------------------------------------------
# [1, 2, 3, 4, 7]
